# %%
import numpy as np

import pandas as pd

# %%
final = pd.read_csv("SystemA.csv", names = ["Time (Days)", "Flux (Normalized)", "EndChar"])%4.1591289
h = final.plot.scatter(x = "Time (Days)", y = "Flux (Normalized)", figsize = (15, 5))
h.set_xlim(3.7, 4.0)
# Out:
# (3.7, 4.0)

# %%
final = pd.read_csv("SystemA.csv", names = ["Time (Days)", "Flux (Normalized)", "EndChar"])%9.03077
s = final.plot.scatter(x = "Time (Days)", y = "Flux (Normalized)", figsize = (15, 5))
s.set_xlim(5.6, 6.3)
s.set_ylim(0.9975, 1.0025)
# Out:
# (0.9975, 1.0025)

# %%
final = pd.read_csv("SystemA.csv", names = ["Time (Days)", "Flux (Normalized)", "EndChar"])%0.789592
f = final.plot.scatter(x = "Time (Days)", y = "Flux (Normalized)", figsize = (20, 5))
f.set_ylim(0.195, 0.215)
# Out:
# (0.195, 0.215)

# %%
final = pd.read_csv("SystemA.csv", names = ["Time (Days)", "Flux (Normalized)", "EndChar"])

final["Phase Planet A"] = final["Time (Days)"].values%4.1591289
h = final.plot.scatter(x = "Phase Planet A", y = "Flux (Normalized)", figsize = (15, 5))
h.set_xlim(3.7, 4.0)

final["Phase Planet B"] = final["Time (Days)"].values%9.03077
s = final.plot.scatter(x = "Phase Planet B", y = "Flux (Normalized)", figsize = (15, 5))
s.set_xlim(5.6, 6.3)
s.set_ylim(0.9975, 1.0025)

final["Phase Planet C"] = final["Time (Days)"].values%0.789592
f = final.plot.scatter(x = "Phase Planet C", y = "Flux (Normalized)", figsize = (20, 5))
f.set_ylim(0.9975, 1.0025)
# Out:
# (0.9975, 1.0025)

# %%
final.to_csv("final.csv")
